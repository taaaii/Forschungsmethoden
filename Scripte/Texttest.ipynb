# %%
from bs4 import BeautifulSoup


class Node:
    def __init__(self, id, label):
        self.id = id
        self.label = label
        self.shape = "ellipse"

    def __str__(self):
        return f'"{self.id}" [label="{self.label}",shape={self.shape}];\n'


class Edge:
    def __init__(self, start, end, label):
        self.start = start
        self.end = end
        self.label = label
        if self.label =="TrauzeugeBei": self.color ="blue"
        elif self.label =="PateVon": self.color = "green"
        elif self.label =="heirat" : self.color = "red"
        else: self.color="black"

    def __str__(self):
        return f'"{self.start}" -> "{self.end}" [label= "{self.label}", color ="{self.color}"];\n'


class Graph(object):
    def __init__(self):
        self.nodes = []
        self.edges = []

    def _add_node(self, node: Node):
        self.nodes.append(node)

    def _add_edge(self, edf: Edge):
        self.edges.append(edf)

    def read_rdf(self, rdf_file):
        with open(rdf_file, 'r', encoding="utf-8") as f:
            text = f.read()
        soup = BeautifulSoup(text, "xml")
        nodes = soup.find_all("rdf:Description")
        for node in nodes:
            self._add_node(Node(node["rdf:about"], node["rdf:name"]))
            for edge in node.find_all(recursive=False):
                print(edge)
                self._add_edge(Edge(node["rdf:about"], edge["rdf:resource"], edge.name))

    def __str__(self):
        e = "".join([edge.__str__() for edge in self.edges])
        n = "".join([node.__str__() for node in self.nodes])
        start = f''' charset="utf-8"; \n\n//Edges \n{e} \n//Nodes \n{n}'''
        return f"digraph {start} "

# %%
graph = Graph()

# %%
graph.read_rdf("Bornschlegel.rdf")
print(graph)
# Out:
# <migr:heirat rdf:resource="Catharina Zinckhin"/>
# <migr:heirat rdf:resource="Anna Maria Waylandt"/>
# <migr:heirat rdf:resource="Barbara Kleißen"/>
# <migr:heirat rdf:resource="migr:402"/>
# <migr:heirat rdf:resource="migr:382"/>
# <migr:heirat rdf:resource="migr:247"/>
# <migr:heirat rdf:resource="migr:382"/>
# <migr:TrauzeugeBei rdf:resource="migr:283"/>
# <migr:TrauzeugeBei rdf:resource="migr:283"/>
# <migr:TrauzeugeBei rdf:resource="migr:540"/>
# <migr:TrauzeugeBei rdf:resource="migr:100"/>
# <migr:TrauzeugeBei rdf:resource="migr:29"/>
# <migr:TrauzeugeBei rdf:resource="migr:402"/>
# <migr:TrauzeugeBei rdf:resource="migr:442"/>
# <migr:TrauzeugeBei rdf:resource="migr:200"/>
# <migr:TrauzeugeBei rdf:resource="migr:215"/>
# <migr:TrauzeugeBei rdf:resource="migr:315"/>
# <migr:PateVon rdf:resource="migr:382"/>
# <migr:PateVon rdf:resource="migr:341"/>
# <migr:PateVon rdf:resource="migr:540"/>
# <migr:PateVon rdf:resource="Anton Gonias Churf"/>
# <migr:Steuer rdf:resource="Zinck"/>
# <migr:TrauzeugeBei rdf:resource="migr:29"/>
# <migr:TrauzeugeBei rdf:resource="migr:200"/>
# <migr:TrauzeugeBei rdf:resource="migr:283"/>
# <migr:TrauzeugeBei rdf:resource="migr:200"/>
# <migr:TrauzeugeBei rdf:resource="migr:246"/>
# <migr:PateVon rdf:resource="migr:246"/>
# <migr:TrauzeugeBei rdf:resource="migr:246"/>
# <migr:TrauzeugeBei rdf:resource="migr:100"/>
# <migr:TrauzeugeBei rdf:resource="migr:315"/>
# <migr:TrauzeugeBei rdf:resource="migr:246"/>
# <migr:heirat rdf:resource="migr:283"/>
# <migr:heirat rdf:resource="migr:29"/>
# <migr:heirat rdf:resource="migr:283"/>
# <migr:TrauzeugeBei rdf:resource="migr:283"/>
# <migr:TrauzeugeBei rdf:resource="migr:283"/>
# <migr:TrauzeugeBei rdf:resource="migr:215"/>
# <migr:TrauzeugeBei rdf:resource="migr:246"/>
# <migr:heirat rdf:resource="migr:215"/>
# <migr:heirat rdf:resource="migr:200"/>
# <migr:PateVon rdf:resource="migr:246"/>
# <migr:TrauzeugeBei rdf:resource="migr:246"/>
# <migr:PateVon rdf:resource="migr:246"/>
# <migr:TrauzeugeBei rdf:resource="migr:246"/>
# <migr:TrauzeugeBei rdf:resource="migr:382"/>
# <migr:TrauZeugeBei rdf:resource="migr:246"/>
# <migr:heirat rdf:resource="migr:442"/>
# <migr:TrauzeugeBei rdf:resource="migr:246"/>
# <migr:TrauzeugeBei rdf:resource="migr:382"/>
# <migr:heirat rdf:resource="migr:402"/>
# <migr:heirat rdf:resource="migr:115"/>
# <migr:TrauzeugeBei rdf:resource="migr:246"/>
# <migr:TrauzeugeBei rdf:resource="migr:540"/>
# digraph  charset="utf-8";
#
# //Edges
# "migr:246" -> "Catharina Zinckhin" [label= "heirat", color ="red"];
# "migr:246" -> "Anna Maria Waylandt" [label= "heirat", color ="red"];
# "migr:246" -> "Barbara Kleißen" [label= "heirat", color ="red"];
# "migr:246" -> "migr:402" [label= "heirat", color ="red"];
# "migr:246" -> "migr:382" [label= "heirat", color ="red"];
# "migr:246" -> "migr:247" [label= "heirat", color ="red"];
# "migr:246" -> "migr:382" [label= "heirat", color ="red"];
# "migr:246" -> "migr:283" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:283" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:540" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:100" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:29" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:402" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:442" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:200" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:215" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:315" [label= "TrauzeugeBei", color ="blue"];
# "migr:246" -> "migr:382" [label= "PateVon", color ="green"];
# "migr:246" -> "migr:341" [label= "PateVon", color ="green"];
# "migr:246" -> "migr:540" [label= "PateVon", color ="green"];
# "migr:246" -> "Anton Gonias Churf" [label= "PateVon", color ="green"];
# "migr:246" -> "Zinck" [label= "Steuer", color ="black"];
# "migr:64" -> "migr:29" [label= "TrauzeugeBei", color ="blue"];
# "migr:64" -> "migr:200" [label= "TrauzeugeBei", color ="blue"];
# "migr:65" -> "migr:283" [label= "TrauzeugeBei", color ="blue"];
# "migr:65" -> "migr:200" [label= "TrauzeugeBei", color ="blue"];
# "migr:73" -> "migr:246" [label= "TrauzeugeBei", color ="blue"];
# "migr:100" -> "migr:246" [label= "PateVon", color ="green"];
# "migr:106" -> "migr:246" [label= "TrauzeugeBei", color ="blue"];
# "migr:115" -> "migr:100" [label= "TrauzeugeBei", color ="blue"];
# "migr:115" -> "migr:315" [label= "TrauzeugeBei", color ="blue"];
# "migr:164" -> "migr:246" [label= "TrauzeugeBei", color ="blue"];
# "migr:200" -> "migr:283" [label= "heirat", color ="red"];
# "migr:200" -> "migr:29" [label= "heirat", color ="red"];
# "migr:215" -> "migr:283" [label= "heirat", color ="red"];
# "migr:241" -> "migr:283" [label= "TrauzeugeBei", color ="blue"];
# "migr:247" -> "migr:283" [label= "TrauzeugeBei", color ="blue"];
# "migr:247" -> "migr:215" [label= "TrauzeugeBei", color ="blue"];
# "migr:249" -> "migr:246" [label= "TrauzeugeBei", color ="blue"];
# "migr:283" -> "migr:215" [label= "heirat", color ="red"];
# "migr:283" -> "migr:200" [label= "heirat", color ="red"];
# "migr:354" -> "migr:246" [label= "PateVon", color ="green"];
# "migr:354" -> "migr:246" [label= "TrauzeugeBei", color ="blue"];
# "migr:369" -> "migr:246" [label= "PateVon", color ="green"];
# "migr:369" -> "migr:246" [label= "TrauzeugeBei", color ="blue"];
# "migr:369" -> "migr:382" [label= "TrauzeugeBei", color ="blue"];
# "migr:376" -> "migr:246" [label= "TrauZeugeBei", color ="black"];
# "migr:402" -> "migr:442" [label= "heirat", color ="red"];
# "migr:419" -> "migr:246" [label= "TrauzeugeBei", color ="blue"];
# "migr:419" -> "migr:382" [label= "TrauzeugeBei", color ="blue"];
# "migr:442" -> "migr:402" [label= "heirat", color ="red"];
# "migr:540" -> "migr:115" [label= "heirat", color ="red"];
# "migr:540" -> "migr:246" [label= "TrauzeugeBei", color ="blue"];
# "Zinck" -> "migr:540" [label= "TrauzeugeBei", color ="blue"];
#
# //Nodes
# "migr:246" [label="Bornschlegel",shape=ellipse];
# "migr:29" [label="Mercklein",shape=ellipse];
# "migr:64" [label="Waltz",shape=ellipse];
# "migr:65" [label="Bischoff",shape=ellipse];
# "migr:73" [label="Bauer",shape=ellipse];
# "migr:100" [label="Agricola",shape=ellipse];
# "migr:106" [label="Stolzenberger",shape=ellipse];
# "migr:115" [label="Zinck",shape=ellipse];
# "migr:164" [label="Knorz",shape=ellipse];
# "migr:200" [label="Schultheis",shape=ellipse];
# "migr:215" [label="Dürr",shape=ellipse];
# "migr:241" [label="Schultheiss",shape=ellipse];
# "migr:247" [label="Fiderling",shape=ellipse];
# "migr:249" [label="Gromb",shape=ellipse];
# "migr:283" [label="Strigler",shape=ellipse];
# "migr:315" [label="Raab",shape=ellipse];
# "migr:341" [label="Beringer",shape=ellipse];
# "migr:354" [label="Gonias",shape=ellipse];
# "migr:369" [label="Saffnoy",shape=ellipse];
# "migr:376" [label="Mützel",shape=ellipse];
# "migr:382" [label="Brentano",shape=ellipse];
# "migr:402" [label="Burger",shape=ellipse];
# "migr:419" [label="Werlein",shape=ellipse];
# "migr:442" [label="Leschendurst",shape=ellipse];
# "migr:540" [label="Onghers",shape=ellipse];
# "Anton Gonias Churf" [label="Anton Gonias Churf",shape=ellipse];
# "Catharina Zinck" [label="Catharina Zinckh",shape=ellipse];
# "Barbara Kleißen" [label="Barbara Kleißen",shape=ellipse];
# "Anna Maria Waylandt" [label="Anna Maria Waylandt",shape=ellipse];
# "Zinck" [label="Zinckh",shape=ellipse];
